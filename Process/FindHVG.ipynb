# %%
import pandas as pd
import numpy as np
import scanpy as sc
import matplotlib.pyplot as plt
import os
import anndata
import scipy as sp
import umap.umap_ as umap
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
dirs="/data02/tguo/space_batch_effect/human_DLPFC_10x/"
sample_name=[151507,151508,151509,151510,151669,151670,151671,151672,151673,151674,151675,151676]
IDX=np.array([0,8])
# IDX=np.arange(len(sample_name))
k=1
adata = sc.read_visium(path=dirs+"scanpy_file/"+str(sample_name[IDX[k]])+"/",
                       count_file="filtered_feature_bc_matrix.h5")
adata.var_names_make_unique()
Ann_df=pd.read_csv(dirs+"input/"+str(sample_name[IDX[k]])+"_label.txt", sep=',', header=0, index_col=0)
Ann_df.columns=['Ground Truth','Sample']
Ann_df.index=[i.split('-')[1]+'-'+i.split('-')[2] for i in Ann_df.index]
adata=adata[Ann_df.index,:]
adata.obs['Ground Truth']=Ann_df.loc[:,'Ground Truth']
sc.pp.highly_variable_genes(adata, flavor="seurat_v3", n_top_genes=5000)
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.obs['batch']=str(sample_name[IDX[k]])
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Trying to set attribute `.obs` of view, copying.

# %%
# vf1=adata.var_names[adata.var['highly_variable']]
# mat1=pd.DataFrame(adata.X.toarray(),columns=adata.var_names,index=adata.obs_names)
# coord1=pd.DataFrame(adata.obsm['spatial'],columns=['x','y'],index=adata.obs_names)
# meta1=adata.obs[['Ground Truth','batch']]
# cells=[str(sample_name[IDX[k]])+'-'+i for i in adata.obs_names]
# mat1.index=cells
# meta1.index=cells
# coord1.index=cells
# meta1.columns=['celltype','batch']

vf2=adata.var_names[adata.var['highly_variable']]
mat2=pd.DataFrame(adata.X.toarray(),columns=adata.var_names,index=adata.obs_names)
coord2=pd.DataFrame(adata.obsm['spatial'],columns=['x','y'],index=adata.obs_names)
meta2=adata.obs[['Ground Truth','batch']]
cells=[str(sample_name[IDX[k]])+'-'+i for i in adata.obs_names]
mat2.index=cells
meta2.index=cells
coord2.index=cells
meta2.columns=['celltype','batch']

vf=np.union1d(vf1,vf2)
mat1=mat1.loc[:,vf]
mat2=mat2.loc[:,vf]
flags=str(sample_name[IDX[0]])
for i in np.arange(1,len(IDX)):
    flags=flags+'-'+str(sample_name[IDX[i]])
flags=flags+"_"

mat1.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[0]])+"_features.txt")
meta1.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[0]])+"_label.txt")
coord1.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[0]])+"_positions.txt")
mat2.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[1]])+"_features.txt")
meta2.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[1]])+"_label.txt")
coord2.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[1]])+"_positions.txt")



# vf3=adata.var_names[adata.var['highly_variable']]
# mat3=pd.DataFrame(adata.X.toarray(),columns=adata.var_names,index=adata.obs_names)
# coord3=pd.DataFrame(adata.obsm['spatial'],columns=['x','y'],index=adata.obs_names)
# meta3=adata.obs[['Ground Truth','batch']]
# cells=[str(sample_name[IDX[k]])+'-'+i for i in adata.obs_names]
# mat3.index=cells
# meta3.index=cells
# coord3.index=cells
# meta3.columns=['celltype','batch']

# vf4=adata.var_names[adata.var['highly_variable']]
# mat4=pd.DataFrame(adata.X.toarray(),columns=adata.var_names,index=adata.obs_names)
# coord4=pd.DataFrame(adata.obsm['spatial'],columns=['x','y'],index=adata.obs_names)
# meta4=adata.obs[['Ground Truth','batch']]
# cells=[str(sample_name[IDX[k]])+'-'+i for i in adata.obs_names]
# mat4.index=cells
# meta4.index=cells
# coord4.index=cells
# meta4.columns=['celltype','batch']

# vf=np.union1d(np.union1d(np.union1d(vf1,vf2),vf3),vf4)
# mat1=mat1.loc[:,vf]
# mat2=mat2.loc[:,vf]
# mat3=mat3.loc[:,vf]
# mat4=mat4.loc[:,vf]
# flags=str(sample_name[IDX[0]])
# for i in np.arange(1,len(IDX)):
#     flags=flags+'-'+str(sample_name[IDX[i]])
# flags=flags+"_"

# mat1.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[0]])+"_features.txt")
# meta1.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[0]])+"_label.txt")
# coord1.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[0]])+"_positions.txt")
# mat2.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[1]])+"_features.txt")
# meta2.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[1]])+"_label.txt")
# coord2.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[1]])+"_positions.txt")
# mat3.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[2]])+"_features.txt")
# meta3.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[2]])+"_label.txt")
# coord3.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[2]])+"_positions.txt")
# mat4.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[3]])+"_features.txt")
# meta4.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[3]])+"_label.txt")
# coord4.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[3]])+"_positions.txt")

# %%
len(vf)
# Out:
# 11074

# %%
# vf1=adata.var_names[adata.var['highly_variable']]
# mat1=pd.DataFrame(adata.X.toarray(),columns=adata.var_names,index=adata.obs_names)
# coord1=pd.DataFrame(adata.obsm['spatial'],columns=['x','y'],index=adata.obs_names)
# meta1=adata.obs[['Ground Truth','batch']]
# cells=[str(sample_name[IDX[k]])+'-'+i for i in adata.obs_names]
# mat1.index=cells
# meta1.index=cells
# coord1.index=cells
# meta1.columns=['celltype','batch']

# vf2=adata.var_names[adata.var['highly_variable']]
# mat2=pd.DataFrame(adata.X.toarray(),columns=adata.var_names,index=adata.obs_names)
# coord2=pd.DataFrame(adata.obsm['spatial'],columns=['x','y'],index=adata.obs_names)
# meta2=adata.obs[['Ground Truth','batch']]
# cells=[str(sample_name[IDX[k]])+'-'+i for i in adata.obs_names]
# mat2.index=cells
# meta2.index=cells
# coord2.index=cells
# meta2.columns=['celltype','batch']

# vf3=adata.var_names[adata.var['highly_variable']]
# mat3=pd.DataFrame(adata.X.toarray(),columns=adata.var_names,index=adata.obs_names)
# coord3=pd.DataFrame(adata.obsm['spatial'],columns=['x','y'],index=adata.obs_names)
# meta3=adata.obs[['Ground Truth','batch']]
# cells=[str(sample_name[IDX[k]])+'-'+i for i in adata.obs_names]
# mat3.index=cells
# meta3.index=cells
# coord3.index=cells
# meta3.columns=['celltype','batch']

# vf4=adata.var_names[adata.var['highly_variable']]
# mat4=pd.DataFrame(adata.X.toarray(),columns=adata.var_names,index=adata.obs_names)
# coord4=pd.DataFrame(adata.obsm['spatial'],columns=['x','y'],index=adata.obs_names)
# meta4=adata.obs[['Ground Truth','batch']]
# cells=[str(sample_name[IDX[k]])+'-'+i for i in adata.obs_names]
# mat4.index=cells
# meta4.index=cells
# coord4.index=cells
# meta4.columns=['celltype','batch']

# vf5=adata.var_names[adata.var['highly_variable']]
# mat5=pd.DataFrame(adata.X.toarray(),columns=adata.var_names,index=adata.obs_names)
# coord5=pd.DataFrame(adata.obsm['spatial'],columns=['x','y'],index=adata.obs_names)
# meta5=adata.obs[['Ground Truth','batch']]
# cells=[str(sample_name[IDX[k]])+'-'+i for i in adata.obs_names]
# mat5.index=cells
# meta5.index=cells
# coord5.index=cells
# meta5.columns=['celltype','batch']

# vf6=adata.var_names[adata.var['highly_variable']]
# mat6=pd.DataFrame(adata.X.toarray(),columns=adata.var_names,index=adata.obs_names)
# coord6=pd.DataFrame(adata.obsm['spatial'],columns=['x','y'],index=adata.obs_names)
# meta6=adata.obs[['Ground Truth','batch']]
# cells=[str(sample_name[IDX[k]])+'-'+i for i in adata.obs_names]
# mat6.index=cells
# meta6.index=cells
# coord6.index=cells
# meta6.columns=['celltype','batch']

# vf7=adata.var_names[adata.var['highly_variable']]
# mat7=pd.DataFrame(adata.X.toarray(),columns=adata.var_names,index=adata.obs_names)
# coord7=pd.DataFrame(adata.obsm['spatial'],columns=['x','y'],index=adata.obs_names)
# meta7=adata.obs[['Ground Truth','batch']]
# cells=[str(sample_name[IDX[k]])+'-'+i for i in adata.obs_names]
# mat7.index=cells
# meta7.index=cells
# coord7.index=cells
# meta7.columns=['celltype','batch']

# vf8=adata.var_names[adata.var['highly_variable']]
# mat8=pd.DataFrame(adata.X.toarray(),columns=adata.var_names,index=adata.obs_names)
# coord8=pd.DataFrame(adata.obsm['spatial'],columns=['x','y'],index=adata.obs_names)
# meta8=adata.obs[['Ground Truth','batch']]
# cells=[str(sample_name[IDX[k]])+'-'+i for i in adata.obs_names]
# mat8.index=cells
# meta8.index=cells
# coord8.index=cells
# meta8.columns=['celltype','batch']

# vf9=adata.var_names[adata.var['highly_variable']]
# mat9=pd.DataFrame(adata.X.toarray(),columns=adata.var_names,index=adata.obs_names)
# coord9=pd.DataFrame(adata.obsm['spatial'],columns=['x','y'],index=adata.obs_names)
# meta9=adata.obs[['Ground Truth','batch']]
# cells=[str(sample_name[IDX[k]])+'-'+i for i in adata.obs_names]
# mat9.index=cells
# meta9.index=cells
# coord9.index=cells
# meta9.columns=['celltype','batch']

# vf10=adata.var_names[adata.var['highly_variable']]
# mat10=pd.DataFrame(adata.X.toarray(),columns=adata.var_names,index=adata.obs_names)
# coord10=pd.DataFrame(adata.obsm['spatial'],columns=['x','y'],index=adata.obs_names)
# meta10=adata.obs[['Ground Truth','batch']]
# cells=[str(sample_name[IDX[k]])+'-'+i for i in adata.obs_names]
# mat10.index=cells
# meta10.index=cells
# coord10.index=cells
# meta10.columns=['celltype','batch']

# vf11=adata.var_names[adata.var['highly_variable']]
# mat11=pd.DataFrame(adata.X.toarray(),columns=adata.var_names,index=adata.obs_names)
# coord11=pd.DataFrame(adata.obsm['spatial'],columns=['x','y'],index=adata.obs_names)
# meta11=adata.obs[['Ground Truth','batch']]
# cells=[str(sample_name[IDX[k]])+'-'+i for i in adata.obs_names]
# mat11.index=cells
# meta11.index=cells
# coord11.index=cells
# meta11.columns=['celltype','batch']

# vf12=adata.var_names[adata.var['highly_variable']]
# mat12=pd.DataFrame(adata.X.toarray(),columns=adata.var_names,index=adata.obs_names)
# coord12=pd.DataFrame(adata.obsm['spatial'],columns=['x','y'],index=adata.obs_names)
# meta12=adata.obs[['Ground Truth','batch']]
# cells=[str(sample_name[IDX[k]])+'-'+i for i in adata.obs_names]
# mat12.index=cells
# meta12.index=cells
# coord12.index=cells
# meta12.columns=['celltype','batch']




vf=np.union1d(np.union1d(np.union1d(np.union1d(np.union1d(np.union1d(np.union1d(np.union1d(np.union1d(np.union1d(np.union1d(vf1,vf2),vf3),vf4),vf5),
                                    vf6),vf7),vf8),vf9),vf10),vf11),vf12)
mat1=mat1.loc[:,vf]
mat2=mat2.loc[:,vf]
mat3=mat3.loc[:,vf]
mat4=mat4.loc[:,vf]
mat5=mat5.loc[:,vf]
mat6=mat6.loc[:,vf]
mat7=mat7.loc[:,vf]
mat8=mat8.loc[:,vf]
mat9=mat9.loc[:,vf]
mat10=mat10.loc[:,vf]
mat11=mat11.loc[:,vf]
mat12=mat12.loc[:,vf]

flags=str(sample_name[IDX[0]])
for i in np.arange(1,len(IDX)):
    flags=flags+'-'+str(sample_name[IDX[i]])
flags=flags+"_"

mat1.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[0]])+"_features.txt")
meta1.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[0]])+"_label.txt")
coord1.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[0]])+"_positions.txt")
mat2.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[1]])+"_features.txt")
meta2.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[1]])+"_label.txt")
coord2.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[1]])+"_positions.txt")
mat3.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[2]])+"_features.txt")
meta3.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[2]])+"_label.txt")
coord3.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[2]])+"_positions.txt")
mat4.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[3]])+"_features.txt")
meta4.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[3]])+"_label.txt")
coord4.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[3]])+"_positions.txt")

mat5.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[4]])+"_features.txt")
meta5.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[4]])+"_label.txt")
coord5.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[4]])+"_positions.txt")
mat6.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[5]])+"_features.txt")
meta6.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[5]])+"_label.txt")
coord6.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[5]])+"_positions.txt")
mat7.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[6]])+"_features.txt")
meta7.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[6]])+"_label.txt")
coord7.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[6]])+"_positions.txt")
mat8.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[7]])+"_features.txt")
meta8.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[7]])+"_label.txt")
coord8.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[7]])+"_positions.txt")

mat9.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[8]])+"_features.txt")
meta9.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[8]])+"_label.txt")
coord9.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[8]])+"_positions.txt")
mat10.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[9]])+"_features.txt")
meta10.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[9]])+"_label.txt")
coord10.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[9]])+"_positions.txt")
mat11.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[10]])+"_features.txt")
meta11.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[10]])+"_label.txt")
coord11.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[10]])+"_positions.txt")
mat12.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[11]])+"_features.txt")
meta12.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[11]])+"_label.txt")
coord12.to_csv(dirs+"gtt_input_scanpy/"+flags+str(sample_name[IDX[11]])+"_positions.txt")
